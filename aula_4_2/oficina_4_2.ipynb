# %% [markdown]
# # 1. Importando as bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='darkgrid')

# %% [markdown]
# Carregando dados para o DataFrame de pandas e exibindo aleatóriamento algumas linhas

# %%
df = sns.load_dataset('mpg')
df.sample(9)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 376  37.0          4          91.0        68.0    2025          18.2
# 122  24.0          4         121.0       110.0    2660          14.0
# 179  22.0          4         121.0        98.0    2945          14.5
# 204  32.0          4          85.0        70.0    1990          17.0
# 130  26.0          4         122.0        80.0    2451          16.5
# 306  28.8          6         173.0       115.0    2595          11.3
# 361  25.4          6         168.0       116.0    2900          12.6
# 210  19.0          6         156.0       108.0    2930          15.5
# 116  16.0          8         400.0       230.0    4278           9.5
#
#      model_year  origin                name
# 376          82   japan  mazda glc custom l
# 122          73  europe           saab 99le
# 179          75  europe         volvo 244dl
# 204          76   japan        datsun b-210
# 130          74     usa          ford pinto
# ...

# %% [markdown]
# # 2. Crie uma visualização que mostre a distribuição conjunta de todas as variáveis quantitativas, diferenciando pelo país de origem (‘origin’). Quais variáveis possuem uma maior correlação?
# Exemplos de variáveis com maior correlação positiva são:
# <br>displacement x weight
# <br>horsepower x displacement
# <br>Exemplos de variáveis com maior correlação negativa são:
# <br>horsepower x acceleration
# <br>mpg x horsepower

# %%
sns.pairplot(df, hue='origin');
# Out:
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# C:\Users\felip\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 3. Sobre a visualização da questão 2, é possível distinguir o país de origem a partir da distribuição de uma variável?
# Sim, passando por parametro a matiz "origin", é gerado a legenda de cores para o gráfico
# # E de uma distribuição conjunta?
# Sim, da mesma forma o parametro passado para a função com a matiz para "origin", a legenda é exibida demonstrando a origem dos países para cada objeto. Desta forma a função pairplot nos exibe um gráfico geral

# %% [markdown]
# # 4. Escolha uma distribuição conjunta em que as variáveis estejam fortemente correlacionadas e crie um gráfico que permita analisar a distribuição conjunta, a reta de regressão e as distribuições marginais.

# %%
sns.jointplot(x='weight' , y='horsepower', kind='reg', data=df);
